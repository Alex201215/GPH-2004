# %% [markdown]
# #### Update pip
# python -m pip install -U pip
# #### Install scikit-image
# python -m pip install -U scikit-image
# #### Install toute autre dépendance possible (à faire s'il y a des bug)
# python -m pip install -U scikit-image[optional]
#
#
# #### Lien pour code inspiré
# https://towardsdatascience.com/image-processing-with-python-application-of-fourier-transformation-5a8584dc175b

# %%
import numpy as np
import scipy as sc
import cv2
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.color import rgb2hsv, rgb2gray, rgb2yuv
from skimage import color, exposure, transform
from skimage.exposure import equalize_hist

# %% [markdown]
# On crée une classe qui nous permet de store une image en entrée comme étant un objet de classe image sur laquelle on peut effectuer des fonctions
#
# Quelques fonctions :
# - np.fft = Classe pour faire des manipulations de fourier
# - np.fft.fft2 = Fait une fft en deux dimensions
# - np.fft.ifft2 = Fait une transformée de fourier interse en 2 dimensions

# %%
class ImageCamera():

    # Fonction d'initialisation
    def __init__(self, fichier_avec_path=None, image_deja_fft=None):
        self.path_fichier = fichier_avec_path
        self.path_fftdeja = image_deja_fft

        if image_deja_fft != None:
            self.image_fft = rgb2gray(imread(f"{self.path_fftdeja}")[:,:,:3])
        else:
            self.image_fft = None

        self.image_ifft = None
        self.image_originale = rgb2gray(imread(f"{self.path_fichier}")[:,:,:3]) # Image originale

    # Calcul de la transformé de fourier
    def calcul_fft(self):
        self.image_fft = np.fft.fftshift(np.fft.fft2(self.image_originale))
        return self.image_fft

    # Calcul de la transformé inverse
    def calcul_ifft(self):
        # Si l'instance de classe n'a pas d'image fft
        if self.image_fft == None and self.image_ifft == None:
            raise ValueError("Il n'y a aucune fft associée à l'objet")
            
        elif self.image_fft != None:
            self.image_ifft = np.fft.ifft2(np.fft.ifftshift(self.image_fft))
            return self.image_ifft
            
        elif self.path_fftdeja != None:
            self.image_ifft = np.fft.ifft2(np.fft.ifftshift(self.image_deja_fft))
            return self.image_deja_if
            
    # Fonction qui gère la compression d'image
    def resize_image(self, taille_voulue):
        pass

    # Affiche la transformé de fourier de l'image objet
    def afficher_fft(self, num=None):
        plt.figure(num=None, figsize=(8,6), dpi=80)
        plt.imshow(np.log(abs(self.image_fft)), cmap='gray')

    # Affiche la transformé de fourier inverse du array fft
    def afficher_ifft(self, num=None):
        plt.figure(num=None, figsize=(8,6), dpi=80)
        plt.imshow((abs(self.image_ifft)), cmap='gray')
        #plt.imshow(np.log(abs(self.image_ifft)), cmap='gray')

    # Affiche l'image originale sans aucun traitement
    def afficher_image_originale(self):
        plt.figure(num=None, figsize=(8,6), dpi=80)
        plt.imshow(self.image_originale, cmap='gray')

# %% [markdown]
# Avec ce format de classe, essayons de créer un objet qui peut être lû, mis en fft et affiché

# %%
objet1 = ImageCamera('LinuxImageTestFFT.png')

# %% [markdown]
# Une fois l'instance de ImageCamera (objet1) créée, il est possible de calculer et afficher la fft

# %%
objet1_fft = objet1.calcul_fft()
objet1.afficher_fft()

# %% [markdown]
# Ensuite, la ifft peut être calculée et affichée

# %%
objet1_ifft = objet1.calcul_ifft()
objet1.afficher_ifft()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 objet1_ifft = objet1.calcul_ifft()
#       2 objet1.afficher_ifft()
#
# Cell In[148], line 24, in ImageCamera.calcul_ifft(self)
#      22 def calcul_ifft(self):
#      23     # Si l'instance de classe n'a pas d'image fft
# ---> 24     if self.image_fft == None and self.image_ifft == None:
#      25         raise ValueError("Il n'y a aucune fft associée à l'objet")
#      27     elif self.image_fft != None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# Et finalement comparée à l'image originaleobjet1.afficher_image_originale()

# %%
#objet1.afficher_image_originale()

# %%
objet2 =  ImageCamera('imagefftdejafait.jpg')
objet2_ifft = objet2.calcul_ifft()

# %%
fft_image = cv2.imread('ImgTest.png', cv2.IMREAD_GRAYSCALE)
ifft_image = np.fft.ifft2(np.fft.ifftshift(fft_image))
ifft_image = np.abs(ifft_image)
cv2.imwrite('reconstructed_image.png', ifft_image)
plt.imshow(ifft_image, cmap='gray')
